# %% [markdown]
# Task 1 : EDA on the Given DataSet

# %%
import pandas as pd
import numpy as np

# %%
import os

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
location = ("/content/Sample_Dataset.csv")

# %%
df = pd.read_csv(location)

# %%
df.head()
# Out:
#          Date  MyWay  Paper Ticket
# 0  01/07/2019  66215          4325
# 1  15/09/2023  63800          7349
# 2  28/12/2021   9994          1882
# 3  11/01/2023  43769          3991
# 4  11/09/2021   3810           685

# %% [markdown]
# Data Exploration: Based on MyWay and Paper Ticket Columns

# %%
df.columns
# Out:
# Index(['Date', 'MyWay', 'Paper Ticket'], dtype='object')

# %%
#MyWay vs PaperTicket
df.plot(kind='scatter', x='MyWay', y='Paper Ticket', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# Time Series Graphs based on the given two methods of Public Transport Patronage

# %%
df['Date'] = pd.to_datetime(df['Date'], format='%d/%m/%Y')
df.sort_values(by='Date', inplace=True)

# %%
df.head(10)
# Out:
#            Date  MyWay  Paper Ticket
# 0    2019-07-01  66215          4325
# 1037 2019-07-02  69181          4764
# 1344 2019-07-03  68410          5086
# 1087 2019-07-04  68258          4750
# 1411 2019-07-05  64088          4919
# 1547 2019-07-06  21297          2885
# 1026 2019-07-07  16414          2026
# 1099 2019-07-08  53424          4238
# 578  2019-07-09  56774          4839
# 1110 2019-07-10  55785          4979

# %%
#Date vs MyWay

def _plot_series(series, series_name, series_index=0):
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['Date']
  ys = series['MyWay']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = df.sort_values('Date', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('Date')
_ = plt.ylabel('MyWay')

# %%
# Date vs Paper Ticket

def _plot_series(series, series_name, series_index=0):
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['Date']
  ys = series['Paper Ticket']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = df.sort_values('Date', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('Date')
_ = plt.ylabel('Paper Ticket')

# %%
#MyWay and Paper Ticket over time

df.plot.line(x='Date', y=['MyWay', 'Paper Ticket'])
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# Observations from the above time-series Graphs:
#
#
# *   There is a drastic fall on MyWay Cards at the beginning of each year.
# *   Pandemic Period witnessed the Maximum Usage of MyWay Cards
# *   Paper Tickets suffered a huge decrement during the first wave of Pandemic
# *   The numbers of Paper Tickets have improved over the years ignoring the
#   sudden dip and  in first quarter of 2024
